# %%
import requests
import pdfplumber
from io import BytesIO

def extract_text_from_pdf_url(pdf_url):
    # Download the PDF
    response = requests.get(pdf_url)
    response.raise_for_status()  # Check if the request was successful

    # Use pdfplumber to read the PDF content
    pdf_text = ""
    with pdfplumber.open(BytesIO(response.content)) as pdf:
        for page in pdf.pages:
            pdf_text += page.extract_text() + "\n"
    
    return pdf_text

# %%
import openai
import os
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv('/security/.env')
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]
print(OPENAI_API_KEY)


def summarize_pdf_text(text, model="gpt-4"):
    

     openai.api_key =OPENAI_API_KEY
  
     response = openai.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": f"Summarize the following text:{text}",
            }
        ],
        model="gpt-3.5-turbo",
     )
    
     return response

# Example usage
pdf_url = "https://mf.nipponindiaim.com/FundsAndPerformance/ProductNotes/NipponIndia-Short-Term-Fund-Jan-2024.pdf"
pdf_text = extract_text_from_pdf_url(pdf_url)
summary = summarize_pdf_text(pdf_text)
print("Summary of PDF Content:")
#print(summary)
# Out:
# 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
# Summary of PDF Content:
